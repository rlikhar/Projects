# %% [markdown]
# # Heart Failure Prediction

# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Importing data

df = pd.read_csv('Data/heart_failure_clinical_records.csv')

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
df.shape
# Out:
# (299, 13)

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %% [markdown]
# ## EDA

# %%
# count of male and female
sns.countplot(x="sex", data=df, palette="Set1")
plt.title("Count of Male and Female")
# Out:
# Text(0.5, 1.0, 'Count of Male and Female')

# %%
sns.boxplot(df.age)
plt.title("Box plot of Age")
# Out:
# Text(0.5, 1.0, 'Box plot of Age')

# %%
# View the distribution of `age` variable
x = df['age']
sns.displot(x, bins=10, color='blue')
plt.show()

# %%
df.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# DEATH_EVENT               0.253729  0.066270                  0.062728
#
#                           diabetes  ejection_fraction  high_blood_pressure  \
# age                      -0.101012           0.060098             0.093289
# anaemia                  -0.012729           0.031557             0.038182
# creatinine_phosphokinase -0.009639          -0.044080            -0.070590
# diabetes                  1.000000          -0.004850            -0.012732
# ejection_fraction        -0.004850           1.000000             0.024445
# high_blood_pressure      -0.012732           0.024445             1.000000
# platelets                 0.092193           0.072177             0.049963
# serum_creatinine         -0.046975          -0.011302            -0.004935
# serum_sodium             -0.089551           0.175902             0.037109
# sex                      -0.157730          -0.148386            -0.104615
# smoking                  -0.147173          -0.067315            -0.055711
# time                      0.033726           0.041729            -0.196439
# DEATH_EVENT              -0.001943          -0.268603             0.079351
#
#                           platelets  serum_creatinine  serum_sodium       sex  \
# age                       -0.052354          0.159187     -0.045966  0.065430
# anaemia                   -0.043786          0.052174      0.041882 -0.094769
# creatinine_phosphokinase   0.024463         -0.016408      0.059550  0.079791
# diabetes                   0.092193         -0.046975     -0.089551 -0.157730
# ejection_fraction          0.072177         -0.011302      0.175902 -0.148386
# high_blood_pressure        0.049963         -0.004935      0.037109 -0.104615
# platelets                  1.000000         -0.041198      0.062125 -0.125120
# serum_creatinine          -0.041198          1.000000     -0.189095  0.006970
# serum_sodium               0.062125         -0.189095      1.000000 -0.027566
# sex                       -0.125120          0.006970     -0.027566  1.000000
# smoking                    0.028234         -0.027414      0.004813  0.445892
# time                       0.010514         -0.149315      0.087640 -0.015608
# DEATH_EVENT               -0.049139          0.294278     -0.195204 -0.004316
#
#                            smoking      time  DEATH_EVENT
# age                       0.018668 -0.224068     0.253729
# anaemia                  -0.107290 -0.141414     0.066270
# creatinine_phosphokinase  0.002421 -0.009346     0.062728
# diabetes                 -0.147173  0.033726    -0.001943
# ejection_fraction        -0.067315  0.041729    -0.268603
# high_blood_pressure      -0.055711 -0.196439     0.079351
# platelets                 0.028234  0.010514    -0.049139
# serum_creatinine         -0.027414 -0.149315     0.294278
# serum_sodium              0.004813  0.087640    -0.195204
# sex                       0.445892 -0.015608    -0.004316
# smoking                   1.000000 -0.022839    -0.012623
# time                     -0.022839  1.000000    -0.526964
# DEATH_EVENT              -0.012623 -0.526964     1.000000

# %%
# plot correlation heatmap to find out correlations
df.corr().style.format("{:.4}").background_gradient(cmap=plt.get_cmap('ocean_r'), axis=1)
# Out:
# <style type="text/css">
# #T_4420f_row0_col0, #T_4420f_row1_col1, #T_4420f_row2_col2, #T_4420f_row3_col3, #T_4420f_row4_col4, #T_4420f_row5_col5, #T_4420f_row6_col6, #T_4420f_row7_col7, #T_4420f_row8_col8, #T_4420f_row9_col9, #T_4420f_row10_col10, #T_4420f_row11_col11, #T_4420f_row12_col12 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_4420f_row0_col1 {
#   background-color: #3c9ebe;
#   color: #f1f1f1;
# }
# #T_4420f_row0_col2 {
#   background-color: #a8d3e2;
#   color: #000000;
# }
# #T_4420f_row0_col3, #T_4420f_row2_col5 {
#   background-color: #b4dae6;
#   color: #000000;
# }
# #T_4420f_row0_col4, #T_4420f_row1_col0, #T_4420f_row4_col5, #T_4420f_row5_col12 {
#   background-color: #4ea6c4;
#   color: #f1f1f1;
# }
# #T_4420f_row0_col5, #T_4420f_row4_col0 {
#   background-color: #399cbd;
#   color: #f1f1f1;
# }
# #T_4420f_row0_col6, #T_4420f_row8_col9 {
#   background-color: #96cbdc;
#   color: #000000;
# }
# #T_4420f_row0_col7, #T_4420f_row12_col6 {
#   background-color: #0f87af;
#   color: #f1f1f1;
# }
# #T_4420f_row0_col8, #T_4420f_row2_col7, #T_4420f_row7_col2, #T_4420f_row10_col0 {
#   background-color: #90c8da;
#   color: #000000;
# }
# #T_4420f_row0_col9, #T_4420f_row4_col1, #T_4420f_row8_col11 {
#   background-color: #4ba5c3;
#   color: #f1f1f1;
# }
# #T_4420f_row0_col10, #T_4420f_row1_col8, #T_4420f_row5_col1, #T_4420f_row8_col1, #T_4420f_row11_col0 {
#   background-color: #69b4cd;
#   color: #f1f1f1;
# }
# #T_4420f_row0_col11, #T_4420f_row1_col2, #T_4420f_row2_col1, #T_4420f_row3_col9, #T_4420f_row4_col12, #T_4420f_row5_col11, #T_4420f_row6_col9, #T_4420f_row7_col8, #T_4420f_row8_col12, #T_4420f_row9_col3, #T_4420f_row10_col3, #T_4420f_row11_col12, #T_4420f_row12_col11 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_4420f_row0_col12, #T_4420f_row12_col1 {
#   background-color: #006b9c;
#   color: #f1f1f1;
# }
# #T_4420f_row1_col3, #T_4420f_row2_col3, #T_4420f_row2_col11, #T_4420f_row7_col4 {
#   background-color: #8dc6d9;
#   color: #000000;
# }
# #T_4420f_row1_col4, #T_4420f_row5_col4 {
#   background-color: #72b9d0;
#   color: #000000;
# }
# #T_4420f_row1_col5, #T_4420f_row5_col8, #T_4420f_row6_col3, #T_4420f_row8_col5, #T_4420f_row9_col0 {
#   background-color: #6cb6ce;
#   color: #000000;
# }
# #T_4420f_row1_col6, #T_4420f_row2_col4, #T_4420f_row7_col6, #T_4420f_row8_col0, #T_4420f_row9_col11 {
#   background-color: #a2d0e0;
#   color: #000000;
# }
# #T_4420f_row1_col7, #T_4420f_row5_col6, #T_4420f_row9_col2 {
#   background-color: #63b1cb;
#   color: #f1f1f1;
# }
# #T_4420f_row1_col9, #T_4420f_row10_col5 {
#   background-color: #c3e1eb;
#   color: #000000;
# }
# #T_4420f_row1_col10, #T_4420f_row6_col12, #T_4420f_row10_col4 {
#   background-color: #cce5ee;
#   color: #000000;
# }
# #T_4420f_row1_col11 {
#   background-color: #e1f0f5;
#   color: #000000;
# }
# #T_4420f_row1_col12, #T_4420f_row3_col6, #T_4420f_row8_col6, #T_4420f_row11_col5, #T_4420f_row12_col8 {
#   background-color: #5aacc8;
#   color: #f1f1f1;
# }
# #T_4420f_row2_col0 {
#   background-color: #badce8;
#   color: #000000;
# }
# #T_4420f_row2_col6 {
#   background-color: #75bad1;
#   color: #000000;
# }
# #T_4420f_row2_col8, #T_4420f_row4_col3 {
#   background-color: #60b0ca;
#   color: #f1f1f1;
# }
# #T_4420f_row2_col9 {
#   background-color: #51a8c5;
#   color: #f1f1f1;
# }
# #T_4420f_row2_col10 {
#   background-color: #84c2d6;
#   color: #000000;
# }
# #T_4420f_row2_col12, #T_4420f_row8_col2 {
#   background-color: #5daec9;
#   color: #f1f1f1;
# }
# #T_4420f_row3_col0 {
#   background-color: #dbedf3;
#   color: #000000;
# }
# #T_4420f_row3_col1, #T_4420f_row3_col2, #T_4420f_row3_col5 {
#   background-color: #9fcfdf;
#   color: #000000;
# }
# #T_4420f_row3_col4, #T_4420f_row9_col12, #T_4420f_row10_col2, #T_4420f_row10_col8 {
#   background-color: #9ccede;
#   color: #000000;
# }
# #T_4420f_row3_col7, #T_4420f_row4_col9 {
#   background-color: #b7dbe7;
#   color: #000000;
# }
# #T_4420f_row3_col8 {
#   background-color: #d2e8f0;
#   color: #000000;
# }
# #T_4420f_row3_col10, #T_4420f_row9_col4 {
#   background-color: #f9fcfd;
#   color: #000000;
# }
# #T_4420f_row3_col11, #T_4420f_row6_col8, #T_4420f_row7_col9, #T_4420f_row8_col10 {
#   background-color: #81c0d5;
#   color: #000000;
# }
# #T_4420f_row3_col12, #T_4420f_row6_col2, #T_4420f_row6_col10, #T_4420f_row7_col10 {
#   background-color: #99ccdd;
#   color: #000000;
# }
# #T_4420f_row4_col2 {
#   background-color: #78bcd2;
#   color: #000000;
# }
# #T_4420f_row4_col6 {
#   background-color: #3399bb;
#   color: #f1f1f1;
# }
# #T_4420f_row4_col7, #T_4420f_row7_col1 {
#   background-color: #66b3cc;
#   color: #f1f1f1;
# }
# #T_4420f_row4_col8 {
#   background-color: #007aa6;
#   color: #f1f1f1;
# }
# #T_4420f_row4_col10, #T_4420f_row5_col7 {
#   background-color: #87c3d7;
#   color: #000000;
# }
# #T_4420f_row4_col11 {
#   background-color: #45a2c1;
#   color: #f1f1f1;
# }
# #T_4420f_row5_col0 {
#   background-color: #48a3c2;
#   color: #f1f1f1;
# }
# #T_4420f_row5_col2, #T_4420f_row10_col7 {
#   background-color: #b1d8e5;
#   color: #000000;
# }
# #T_4420f_row5_col3, #T_4420f_row6_col5, #T_4420f_row7_col5, #T_4420f_row10_col6 {
#   background-color: #8ac4d8;
#   color: #000000;
# }
# #T_4420f_row5_col9, #T_4420f_row6_col7 {
#   background-color: #c6e2ec;
#   color: #000000;
# }
# #T_4420f_row5_col10, #T_4420f_row6_col11, #T_4420f_row7_col3, #T_4420f_row10_col12 {
#   background-color: #a5d2e1;
#   color: #000000;
# }
# #T_4420f_row6_col0 {
#   background-color: #cfe7ef;
#   color: #000000;
# }
# #T_4420f_row6_col1 {
#   background-color: #c9e4ed;
#   color: #000000;
# }
# #T_4420f_row6_col4 {
#   background-color: #7bbdd3;
#   color: #000000;
# }
# #T_4420f_row7_col0 {
#   background-color: #2190b5;
#   color: #f1f1f1;
# }
# #T_4420f_row7_col11, #T_4420f_row10_col1 {
#   background-color: #e7f3f7;
#   color: #000000;
# }
# #T_4420f_row7_col12 {
#   background-color: #006397;
#   color: #f1f1f1;
# }
# #T_4420f_row8_col3 {
#   background-color: #bddee9;
#   color: #000000;
# }
# #T_4420f_row8_col4 {
#   background-color: #1288b0;
#   color: #f1f1f1;
# }
# #T_4420f_row8_col7 {
#   background-color: #fcfefe;
#   color: #000000;
# }
# #T_4420f_row9_col1 {
#   background-color: #d8ebf2;
#   color: #000000;
# }
# #T_4420f_row9_col5 {
#   background-color: #deeef4;
#   color: #000000;
# }
# #T_4420f_row9_col6 {
#   background-color: #eaf4f8;
#   color: #000000;
# }
# #T_4420f_row9_col7 {
#   background-color: #93c9db;
#   color: #000000;
# }
# #T_4420f_row9_col8 {
#   background-color: #abd5e3;
#   color: #000000;
# }
# #T_4420f_row9_col10 {
#   background-color: #00377a;
#   color: #f1f1f1;
# }
# #T_4420f_row10_col9 {
#   background-color: #00397b;
#   color: #f1f1f1;
# }
# #T_4420f_row10_col11 {
#   background-color: #aed7e4;
#   color: #000000;
# }
# #T_4420f_row11_col1 {
#   background-color: #3f9fbf;
#   color: #f1f1f1;
# }
# #T_4420f_row11_col2, #T_4420f_row12_col10 {
#   background-color: #007ea9;
#   color: #f1f1f1;
# }
# #T_4420f_row11_col3 {
#   background-color: #0072a1;
#   color: #f1f1f1;
# }
# #T_4420f_row11_col4 {
#   background-color: #0070a0;
#   color: #f1f1f1;
# }
# #T_4420f_row11_col6 {
#   background-color: #0078a5;
#   color: #f1f1f1;
# }
# #T_4420f_row11_col7 {
#   background-color: #42a0c0;
#   color: #f1f1f1;
# }
# #T_4420f_row11_col8 {
#   background-color: #006498;
#   color: #f1f1f1;
# }
# #T_4420f_row11_col9 {
#   background-color: #0080aa;
#   color: #f1f1f1;
# }
# #T_4420f_row11_col10 {
#   background-color: #0381ab;
#   color: #f1f1f1;
# }
# #T_4420f_row12_col0 {
#   background-color: #003c7d;
#   color: #f1f1f1;
# }
# #T_4420f_row12_col2 {
#   background-color: #006c9d;
#   color: #f1f1f1;
# }
# #T_4420f_row12_col3 {
#   background-color: #007ba7;
#   color: #f1f1f1;
# }
# #T_4420f_row12_col4 {
#   background-color: #7ebed4;
#   color: #000000;
# }
# #T_4420f_row12_col5 {
#   background-color: #00689a;
#   color: #f1f1f1;
# }
# #T_4420f_row12_col7 {
#   background-color: #003176;
#   color: #f1f1f1;
# }
# #T_4420f_row12_col9 {
#   background-color: #007da8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4420f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4420f_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_4420f_level0_col1" class="col_heading level0 col1" >anaemia</th>
#       <th id="T_4420f_level0_col2" class="col_heading level0 col2" >creatinine_phosphokinase</th>
#       <th id="T_4420f_level0_col3" class="col_heading level0 col3" >diabetes</th>
#       <th id="T_4420f_level0_col4" class="col_heading level0 col4" >ejection_fraction</

# %%
# Spliting target variable

X = df.drop(['DEATH_EVENT'], axis=1)
y = df['DEATH_EVENT']

# %%
## Split data into separate training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 123)

# %%
# check the shape of X_train and X_test
X_train.shape, X_test.shape
# Out:
# ((239, 12), (60, 12))

# %%
# instantiate the classifier 
rfc = RandomForestClassifier(random_state=123)

# %%
# fit the model
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=123)

# %%
# Predict the Test set results
y_pred = rfc.predict(X_test)

# %%
accuracy_score(y_test, y_pred) *100
# Out:
# 80.0

# %%
# Print the Confusion Matrix and slice it into four pieces
cm = confusion_matrix(y_test, y_pred)
print('Confusion matrix\n', cm)
# Out:
# Confusion matrix
#  [[31  4]
#  [ 8 17]]

# %%
# visualize confusion matrix with seaborn heatmap

cm_matrix = pd.DataFrame(data=cm, columns=['Actual Positive:1', 'Actual Negative:0'], 
                                 index=['Predict Positive:1', 'Predict Negative:0'])

sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='ocean_r')
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84        35
#            1       0.81      0.68      0.74        25
#
#     accuracy                           0.80        60
#    macro avg       0.80      0.78      0.79        60
# weighted avg       0.80      0.80      0.80        60

# %%
from sklearn.model_selection import GridSearchCV

# %%
# parameters
param_grid = { 
    'n_estimators': [200, 500, 1000, 2000],
    'max_depth' : [4,5,6,7,8,9],
    'criterion' :['gini', 'entropy', 'log_loss'],
    'min_samples_leaf':[1,2,3,4,5]
}

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 3)
CV_rfc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=123),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [4, 5, 6, 7, 8, 9],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'n_estimators': [200, 500, 1000, 2000]})

# %%
CV_rfc.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 4,
#  'min_samples_leaf': 3,
#  'n_estimators': 500}

# %%
rfr_model = RandomForestClassifier(criterion='gini',max_depth=4,max_features='auto',n_estimators=200)

# %%
rfr_model.fit(X_train, y_train)
# Out:
# /home/rahul/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(max_depth=4, max_features='auto', n_estimators=200)

# %%
# Predict the Test set results
y_pred_rfr = rfr_model.predict(X_test)

# %%
rfr_acc = accuracy_score(y_test, y_pred_rfr) *100
f1_rfr = f1_score(y_test, y_pred_rfr)
pre_rfr = precision_score(y_test, y_pred_rfr)
recall_rfr = recall_score(y_test, y_pred_rfr)

# %%
resultsRFR = pd.DataFrame({'Accuracy':rfr_acc,
                          'f1_score':f1_rfr,
                          'Precision_score': pre_rfr,
                          'Recall_Score':recall_rfr }
                           ,index=['Random Forest Classifier'])

resultsRFR
# Out:
#                           Accuracy  f1_score  Precision_score  Recall_Score
# Random Forest Classifier      80.0  0.714286         0.882353           0.6

# %%
gbm_clf = GradientBoostingClassifier()

# %%
gbm_clf.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
# Predict the Test set results
y_pred_gbm = gbm_clf.predict(X_test)

# %%
gbm_acc = accuracy_score(y_test, y_pred_gbm) *100
f1_gbm = f1_score(y_test, y_pred_gbm)
pre_gbm = precision_score(y_test, y_pred_gbm)
recall_gbm = recall_score(y_test, y_pred_gbm)

# %%
resultsGBM = pd.DataFrame({'Accuracy':gbm_acc,
                          'f1_score':f1_gbm,
                          'Precision_score': pre_gbm,
                          'Recall_Score':recall_gbm }
                           ,index=['Gradient Boosting Classifier'])


results2 = pd.concat([resultsGBM,resultsRFR])

results2
# Out:
#                                Accuracy  f1_score  Precision_score  \
# Gradient Boosting Classifier  81.666667  0.755556         0.850000
# Random Forest Classifier      80.000000  0.714286         0.882353
#
#                               Recall_Score
# Gradient Boosting Classifier          0.68
# Random Forest Classifier              0.60
